# %%
import os
os.chdir("/content/drive/Shareddrives/yujung kim/Study/Python/time_series/notebook/03_Deeplearning_models")

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timezone, timedelta, time
from tqdm.auto import tqdm

# %%
import src.transformer as tf

from torch.utils.data import DataLoader
import torch
from torch import nn, Tensor
import torch.nn.functional as F
from torch.nn import TransformerEncoder, TransformerEncoderLayer
import torch.optim as optim

# %%
with open('../../data/pv_forecast.pickle', 'rb') as f:
    pv = pickle.load(f)

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
power_scaler = MinMaxScaler()
power_scaler.fit(pv[['power']])
pv['power_scale'] = power_scaler.transform(pv[['power']])

# %%
x_scaler = MinMaxScaler()
x_scaler.fit(pv[['dwpt', 'rhum', 'wspd', 'pres']])
pv[['dwpt', 'rhum', 'wspd', 'pres']] = x_scaler.transform(pv[['dwpt', 'rhum', 'wspd', 'pres']])

# %%
pv = pv.set_index('datetime')

# %%
tz = timezone(timedelta(hours=-6))
pv_train = pv.loc[:datetime(2006,12,21,23,tzinfo=tz)]
pv_test = pv.loc[datetime(2006,12,15,00,tzinfo=tz):datetime(2006,12,30,23,tzinfo=tz)]

# %% [markdown]
# # data loader
#
# - torch 에서 LSTM 의 경우
#   - input: (seq_len, batch, input_size)
#   - output: (seq_len, batch, num_directions * hidden_size)

# %%
iw = 24*7
ow = 24
num_feature = 5

train_dataset = tf.windowDataset(pv_train[['power_scale', 'rhum', 'dwpt', 'wspd', 'pres']], input_window=iw, output_window=ow, num_feature=num_feature, stride=24)
test_dataset = tf.windowDataset(pv_test[['power_scale', 'rhum', 'dwpt', 'wspd', 'pres']], input_window=iw, output_window=ow, num_feature=num_feature, stride=24)

train_loader = DataLoader(train_dataset, batch_size=64)
test_loader = DataLoader(test_dataset, batch_size=16)

# %%
len(train_loader)
# Out:
# 6

# %%
len(test_loader)
# Out:
# 1

# %% [markdown]
# # transformer
#
# - 시계열 데이터 transformer 적용이 목표이기 때문에 최대한 간단한 구조로 적용
#
# - positional embedding 적용 x
#
# - encoder, decoder 모두 1개의 layer
#
# - target seq의 경우 teacher force prop 1/0 두가지로 적용

# %% [markdown]
# # teacher forcing = 1

# %%
# !pip install wandb

# %%
import wandb

# %%
wandb.init(name='basic', project="transformer", entity="yyyyyjkim")
# Out:
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/notebook/03_Deeplearning_models/wandb/run-20220425_063711-3hdj3yh9</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/transformer/runs/3hdj3yh9" target="_blank">basic</a></strong> to <a href="https://wandb.ai/yyyyyjkim/transformer" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/yyyyyjkim/transformer/runs/3hdj3yh9?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
wandb.config = {
    "learning_rate": 0.001,
    "epochs": 100,
    "d_model": 5,
    "nhead": 5,
    "num_encoder_layers": 1,
    "num_decoder_layers": 1,
    "dim_feedforward": 128
}

# %%
device='cpu'
model = nn.Transformer(d_model=wandb.config["d_model"], 
                       nhead=wandb.config["nhead"], 
                       num_encoder_layers=wandb.config["num_encoder_layers"], 
                       num_decoder_layers=wandb.config["num_decoder_layers"], 
                       dim_feedforward=wandb.config["dim_feedforward"], 
                       batch_first=True).to(device)

optimizer = optim.Adam(model.parameters(), lr = wandb.config['learning_rate'])
criterion = nn.MSELoss()

# %%
# 파라미터 수 계산
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 3,256 trainable parameters

# %%
# 파라미터 초기화
def initialize_weights(m):
    if hasattr(m, 'weight') and m.weight.dim() > 1:
        nn.init.xavier_uniform_(m.weight.data)

model.apply(initialize_weights)
# Out:
# Transformer(
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=5, out_features=5, bias=True)
#         )
#         (linear1): Linear(in_features=5, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=128, out_features=5, bias=True)
#         (norm1): LayerNorm((5,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((5,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm): LayerNorm((5,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder): TransformerDecoder(
#     (layers): ModuleList(
#       (0): TransformerDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=5, out_features=5, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=5, out_features=5, bias=True)
#         )
#         (linear1): Linear(in_features=5, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=128, out_features=5, bias=True)
#         (norm1): LayerNorm((5,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((5,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((5,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm): LayerNorm((5,), eps=1e-05, elementwise_affine=True)
#   )
# )

# %%
wandb.watch(model, log='all', log_freq=10)

target_mask = model.generate_square_subsequent_mask(24).to(device)

pbar = tqdm(range(wandb.config['epochs']))
for epoch in pbar:
    pred, true, train_loss = tf.train(model, train_loader, target_mask, optimizer, criterion, device='cpu')
    pred, true, test_loss = tf.predict(model, test_loader, target_mask, criterion, device='cpu')
    pred_real, true_real, test_loss_real = tf.predict_real(model, test_loader, criterion, max_len=24, device='cpu')
    wandb.log({"train_loss": train_loss, "test_loss": test_loss, "test_loss_real": test_loss_real})

    pbar.set_postfix(loss=f"train_loss: {train_loss:.5f}")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_loss_real</td><td>▇█▂▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.01306</td></tr><tr><td>test_loss_real</td><td>0.15653</td></tr><tr><td>train_loss</td><td>0.01767</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">basic</strong>: <a href="https://wandb.ai/yyyyyjkim/transformer/runs/3hdj3yh9" target="_blank">https://wandb.ai/yyyyyjkim/transformer/runs/3hdj3yh9</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220425_063711-3hdj3yh9/logs</code>

# %%
pred = power_scaler.inverse_transform(pred[:,:,0].reshape(-1,1))
true = power_scaler.inverse_transform(true[:,:,0].reshape(-1,1))

# %%
pv_test = pv.loc[datetime(2006,12,22,00,tzinfo=tz):datetime(2006,12,30,23,tzinfo=tz)].copy()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(30,5))

sns.lineplot(pv_train.loc[datetime(2006,12,1,00,tzinfo=tz):].index, pv_train.loc[datetime(2006,12,1,00,tzinfo=tz):]['power'])
sns.lineplot(pv_test.index, true.reshape(-1), label='True')
sns.lineplot(pv_test.index, pred.reshape(-1), label='Pred')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pred = power_scaler.inverse_transform(pred_real[:,:,0].reshape(-1,1))
true = power_scaler.inverse_transform(true_real[:,:,0].reshape(-1,1))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(30,5))

sns.lineplot(pv_train.loc[datetime(2006,12,1,00,tzinfo=tz):].index, pv_train.loc[datetime(2006,12,1,00,tzinfo=tz):]['power'])
sns.lineplot(pv_test.index, true.reshape(-1), label='True')
sns.lineplot(pv_test.index, pred.reshape(-1), label='Pred')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
