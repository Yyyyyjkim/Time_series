# %%
import os
os.chdir("/content/drive/Shareddrives/yujung kim/Study/Python/time_series")

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timezone, timedelta, time

import seaborn as sns
import matplotlib.pyplot as plt

# %%
import torch
from torch import nn, Tensor
import torch.nn.functional as F
from torch.nn import TransformerEncoder, TransformerEncoderLayer
from torch.utils.data import dataset
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

from tqdm.auto import tqdm
from typing import Optional, Tuple

# %%
import torch
import torch.nn as nn
from torch.nn.utils import weight_norm

# %%
with open('data/pv.pickle', 'rb') as f:
    pv = pickle.load(f)

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
power_scaler = MinMaxScaler()
power_scaler.fit(pv[['power']])
pv['power_scale'] = power_scaler.transform(pv[['power']])

# %%
x_scaler = MinMaxScaler()
x_scaler.fit(pv[['alt', 'azi', 'temp', 'dwpt', 'rhum', 'wspd', 'pres']])
pv[['alt', 'azi', 'temp', 'dwpt', 'rhum', 'wspd', 'pres']] = x_scaler.transform(pv[['alt', 'azi', 'temp', 'dwpt', 'rhum', 'wspd', 'pres']])

# %%
pv = pv.set_index('datetime')

# %%
tz = timezone(timedelta(hours=-6))
pv_train = pv.loc[:datetime(2006,11,30,23,tzinfo=tz)]
pv_val = pv.loc[datetime(2006,11,24,00,tzinfo=tz):datetime(2006,12,20,23,tzinfo=tz)]
pv_test = pv.loc[datetime(2006,12,14,00,tzinfo=tz):datetime(2006,12,31,23,tzinfo=tz)]

# %% [markdown]
# # data loader

# %%
class windowDataset(Dataset):
    def __init__(self, y, input_window, output_window, num_feature, data_comp, stride=1):
        #총 데이터의 개수
        L = y.shape[0]
        # seq_len
        num_samples = (L - input_window - output_window) // stride + 1

        #input과 output : shape = (window 크기, sample 개수)
        X = np.zeros([input_window, num_samples, num_feature])
        Y = np.zeros([output_window, num_samples, num_feature])

        for i in np.arange(num_samples):
            start_x = stride*i
            end_x = start_x + input_window
            X[:,i,:] = y[start_x:end_x]
            # print(X.shape)

            start_y = stride*i + input_window
            end_y = start_y + output_window
            Y[:,i] = y[start_y:end_y]
            # print(Y.shape)

        X = X.reshape(X.shape[0], X.shape[1], num_feature).transpose((1,0,2)) # (seq_len, input_window, feature)
        Y = Y.reshape(Y.shape[0], Y.shape[1], num_feature).transpose((1,0,2)) # (seq_len, output_window, 1=power)

        if data_comp==1:
            Y = Y[:,:,0][:,:,None]
            print(Y.shape)

        if data_comp==2:
            X = Y[:,:,1:].copy()
            Y = Y[:,:,0][:,:,None]
            print(X.shape)
            print(Y.shape)
        
        self.x = X
        self.y = Y
        self.len = len(X)

    def __getitem__(self, i):
        return self.x[i], self.y[i]

    def __len__(self):
        return self.len

# %% [markdown]
# # model

# %%
# weight init 0.01 -> 0.1로 증가

# 뒷부분 padding 제외하는 함수
class Chomp1d(nn.Module):
    def __init__(self, chomp_size):
        super(Chomp1d, self).__init__()
        self.chomp_size = chomp_size

    def forward(self, x):
        return x[:, :, :-self.chomp_size].contiguous()


class TemporalBlock(nn.Module):
    def __init__(self, n_inputs, n_outputs, kernel_size, stride, dilation, padding, dropout=0.2):
        super(TemporalBlock, self).__init__()
        self.conv1 = weight_norm(nn.Conv1d(n_inputs, n_outputs, kernel_size,
                                           stride=stride, padding=padding, dilation=dilation))
        self.chomp1 = Chomp1d(padding) # 뒷 padding 부분 제거?
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout)

        self.conv2 = weight_norm(nn.Conv1d(n_outputs, n_outputs, kernel_size,
                                           stride=stride, padding=padding, dilation=dilation))
        self.chomp2 = Chomp1d(padding)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout)

        self.net = nn.Sequential(self.conv1, self.chomp1, self.relu1, self.dropout1,
                                 self.conv2, self.chomp2, self.relu2, self.dropout2)
        self.downsample = nn.Conv1d(n_inputs, n_outputs, 1) if n_inputs != n_outputs else None
        self.relu = nn.ReLU()
        self.init_weights()

    def init_weights(self):
        self.conv1.weight.data.normal_(0, 0.01)
        self.conv2.weight.data.normal_(0, 0.01)
        if self.downsample is not None:
            self.downsample.weight.data.normal_(0, 0.01)

    def forward(self, x):
        out = self.net(x)
        res = x if self.downsample is None else self.downsample(x)
        return self.relu(out + res)


class TemporalConvNet(nn.Module):
    def __init__(self, num_inputs, num_channels, kernel_size=2, dropout=0.2):
        super(TemporalConvNet, self).__init__()
        layers = []
        num_levels = len(num_channels)
        for i in range(num_levels):
            dilation_size = 2 ** i
            in_channels = num_inputs if i == 0 else num_channels[i-1]
            out_channels = num_channels[i]
            layers += [TemporalBlock(in_channels, out_channels, kernel_size, stride=1, dilation=dilation_size,
                                     padding=(kernel_size-1) * dilation_size, dropout=dropout)] 

        self.network = nn.Sequential(*layers)

    def forward(self, x):
        return self.network(x)

# %%
class TCN(nn.Module):
    def __init__(self, input_size, output_size, num_channels, kernel_size, dropout):
        super(TCN, self).__init__()
        self.tcn = TemporalConvNet(input_size, num_channels, kernel_size=kernel_size, dropout=dropout)
        self.linear = nn.Linear(num_channels[-1], output_size)
        self.init_weights()

    def init_weights(self):
        self.linear.weight.data.normal_(0, 0.1)

    def forward(self, x):
        y1 = self.tcn(x)
        return self.linear(y1.transpose(1, 2))

# %% [markdown]
# # wandb

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.12.16-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 4.9 MB/s
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 70.3 MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 64.6 MB/s
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.8 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=8960a75b4a12f8277b61d9612780be6fd5f536debdd72ed0e20f12a84deaa5b0
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 wandb-0.12.16

# %%
import wandb

# %% [markdown]
# # data component 1

# %%
iw = 24*7
ow = 24
num_feature = 8

train_dataset = windowDataset(pv_train[['power_scale', 'alt', 'azi', 'temp', 'dwpt', 'rhum', 'wspd', 'pres']], 
                              input_window=iw, output_window=ow, num_feature=num_feature, data_comp=1, stride=ow)
valid_dataset = windowDataset(pv_val[['power_scale', 'alt', 'azi', 'temp', 'dwpt', 'rhum', 'wspd', 'pres']], 
                             input_window=iw, output_window=ow, num_feature=num_feature, data_comp=1, stride=ow)
test_dataset = windowDataset(pv_test[['power_scale', 'alt', 'azi', 'temp', 'dwpt', 'rhum', 'wspd', 'pres']], 
                             input_window=iw, output_window=ow, num_feature=num_feature, data_comp=1, stride=ow)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(valid_dataset, batch_size=16)
test_loader = DataLoader(test_dataset, batch_size=16)
# Out:
# (327, 24, 1)
# (20, 24, 1)
# (11, 24, 1)

# %%
a = next(iter(train_loader))
print(a[0].shape)
print(a[1].shape)
# Out:
# torch.Size([64, 168, 8])
# torch.Size([64, 24, 1])

# %%
def train(model, train_loader, optimizer, criterion, device='cuda'):
    model.train()
    total_loss = 0.0

    for x, y in train_loader:
        optimizer.zero_grad()
        x = x.permute(0,2,1).to(device).float().contiguous()
        y = y.permute(0,2,1).to(device).float().contiguous()

        out = model(x).permute(0,2,1)

        # print(f"x shape: {x.shape}")
        # print(f"y shape: {y.shape}")
        # print(f"pred shape: {out.shape}")
        # print(f"final y shape: {y[:,0,:y.shape[2]].shape}")
        # print(f"final pred shape: {out[:,0,:y.shape[2]].shape}")

        loss = criterion(y[:,0,:y.shape[2]], out[:,0,:y.shape[2]])
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 3)

        optimizer.step()
        total_loss += loss.cpu().item()
    train_loss = total_loss/len(train_loader)

    return out.detach().cpu().numpy(), y.detach().cpu().numpy(), train_loss

def predict(model, test_loader, criterion, device='cuda', file_name=None):
    model.eval()

    total_loss = 0.0
    outputs = []
    ys = []

    for t, (x, y) in enumerate(test_loader):
        x = x.permute(0,2,1).to(device).float()
        y = y.permute(0,2,1).to(device).float()

        with torch.no_grad():
            out = model(x).permute(0,2,1)
        outputs.append(list(out.detach().cpu().numpy()))
        ys.append(list(y.detach().cpu().numpy()))
        loss = criterion(y[:,:,0], out[:,:,0])
        # loss = criterion(y, out)
        total_loss += loss.cpu().item()

    test_loss = total_loss/len(test_loader)
    # print(f"test loss: {(total_loss/len(test_loader)):.5f}")

    if file_name:
        torch.save(model.state_dict(), file_name)

    return np.array(sum(outputs,[])), np.array(sum(ys,[])), test_loss

# %% [markdown]
# # parameter search

# %%
from itertools import product

lr = [0.0001, 0.0005, 0.001]
num_hidden = [10,20,30]
num_levels = [4,6,8]
kernel_size = [3,5,7,10]
dropout = [0.0, 0.25, 0.5]

params_ = [lr, num_hidden, num_levels, kernel_size, dropout]
params_ = list(product(*params_))

# %%
for _, param in enumerate(tqdm(params_)):

    wandb.init(name=str(param), project="TCN_data_composition_1", entity="yyyyyjkim")

    (lr, num_hidden, num_levels, kernel_size, dropout) = param
    wandb.config = {
        "learning_rate": lr,
        "epochs": 1000,
        "input_size": 8,
        "output_size": 1,
        "num_channels": [num_hidden]*num_levels,
        "kernel_size": kernel_size, 
        "dropout": dropout
    }

    device='cpu'
    model = TCN(input_size=wandb.config['input_size'], output_size=wandb.config['output_size'], num_channels=wandb.config['num_channels'], kernel_size=wandb.config['kernel_size'], dropout=wandb.config['dropout']).to(device)
    optimizer = optim.Adam(model.parameters(), lr=wandb.config['learning_rate'])
    criterion = nn.MSELoss()

    wandb.watch(model, log='all', log_freq=10)

    val_loss_min = 100
    file_name = f"model/TCN_data_composition_1/{str(param)}"

    pbar = tqdm(range(wandb.config['epochs']))
    for epoch in pbar:
        *result_train, train_loss = train(model, train_loader, optimizer, criterion, device=device)
        *result_val, val_loss = predict(model, val_loader, criterion, device=device)
        *result_test, test_loss = predict(model, test_loader, criterion, device=device)

        if val_loss < val_loss_min:
            val_loss_min = val_loss
            torch.save(model.state_dict(), file_name)
            # print(f"epoch: {epoch} / val_loss: {val_loss:.5f} / test_loss: {test_loss:.5f}")

        wandb.log({"train_loss": train_loss, "val_loss": val_loss, "test_loss": test_loss, "val_loss_min": val_loss_min})

        pbar.set_postfix(loss=f"train_loss: {train_loss:.5f} / val_loss: {val_loss:.5f} / test_loss: {test_loss:.5f}")

    wandb.finish()
# Out:
#   0%|          | 0/324 [00:00<?, ?it/s]
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_070335-14mzg92o</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/14mzg92o" target="_blank">(0.0001, 10, 4, 3, 0.0)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▆▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▆▃▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▆▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▆▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>9e-05</td></tr><tr><td>train_loss</td><td>0.01233</td></tr><tr><td>val_loss</td><td>9e-05</td></tr><tr><td>val_loss_min</td><td>4e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 4, 3, 0.0)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/14mzg92o" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/14mzg92o</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_070335-14mzg92o/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_070822-1i7hb8ks</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1i7hb8ks" target="_blank">(0.0001, 10, 4, 3, 0.25)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>▃█▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▅▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▃█▅▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>████▇▇▆▆▅▅▅▅▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00024</td></tr><tr><td>train_loss</td><td>0.01557</td></tr><tr><td>val_loss</td><td>0.00023</td></tr><tr><td>val_loss_min</td><td>2e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 4, 3, 0.25)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1i7hb8ks" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1i7hb8ks</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_070822-1i7hb8ks/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_071333-1q4w9x23</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1q4w9x23" target="_blank">(0.0001, 10, 4, 3, 0.5)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>▄▂▅▇██▆▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅</td></tr><tr><td>train_loss</td><td>█▆▅▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄▂▅▇██▆▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▅</td></tr><tr><td>val_loss_min</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00207</td></tr><tr><td>train_loss</td><td>0.01468</td></tr><tr><td>val_loss</td><td>0.00216</td></tr><tr><td>val_loss_min</td><td>0.0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 4, 3, 0.5)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1q4w9x23" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1q4w9x23</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_071333-1q4w9x23/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_071842-39thvra2</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/39thvra2" target="_blank">(0.0001, 10, 4, 5, 0.0)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▁▁▃▅▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▃▅▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>1e-05</td></tr><tr><td>train_loss</td><td>0.01322</td></tr><tr><td>val_loss</td><td>1e-05</td></tr><tr><td>val_loss_min</td><td>0.0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 4, 5, 0.0)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/39thvra2" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/39thvra2</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_071842-39thvra2/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_072415-1y9e9kit</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1y9e9kit" target="_blank">(0.0001, 10, 4, 5, 0.25)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>▄▂█▆▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▅▂█▆▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00011</td></tr><tr><td>train_loss</td><td>0.01446</td></tr><tr><td>val_loss</td><td>0.00011</td></tr><tr><td>val_loss_min</td><td>0.0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 4, 5, 0.25)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1y9e9kit" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1y9e9kit</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_072415-1y9e9kit/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_073018-pk0hkfpf</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/pk0hkfpf" target="_blank">(0.0001, 10, 4, 5, 0.5)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▇▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▆▃▃▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▅▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>██▅▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00146</td></tr><tr><td>train_loss</td><td>0.01428</td></tr><tr><td>val_loss</td><td>0.00156</td></tr><tr><td>val_loss_min</td><td>0.00011</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 4, 5, 0.5)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/pk0hkfpf" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/pk0hkfpf</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_073018-pk0hkfpf/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_073629-6suk5sul</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/6suk5sul" target="_blank">(0.0001, 10, 4, 7, 0.0)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00019</td></tr><tr><td>train_loss</td><td>0.01321</td></tr><tr><td>val_loss</td><td>0.00029</td></tr><tr><td>val_loss_min</td><td>0.00023</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 4, 7, 0.0)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/6suk5sul" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/6suk5sul</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_073629-6suk5sul/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_074301-3se9uezu</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/3se9uezu" target="_blank">(0.0001, 10, 4, 7, 0.25)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>▁█▆▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁█▆▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00023</td></tr><tr><td>train_loss</td><td>0.01529</td></tr><tr><td>val_loss</td><td>0.00018</td></tr><tr><td>val_loss_min</td><td>0.0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 4, 7, 0.25)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/3se9uezu" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/3se9uezu</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_074301-3se9uezu/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_074959-2go9ey03</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2go9ey03" target="_blank">(0.0001, 10, 4, 7, 0.5)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▆▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▆▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▆▄▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▆▄▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00058</td></tr><tr><td>train_loss</td><td>0.0153</td></tr><tr><td>val_loss</td><td>0.0007</td></tr><tr><td>val_loss_min</td><td>0.00011</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 4, 7, 0.5)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2go9ey03" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2go9ey03</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_074959-2go9ey03/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_075704-olwamr3s</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/olwamr3s" target="_blank">(0.0001, 10, 4, 10, 0.0)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>2e-05</td></tr><tr><td>train_loss</td><td>0.01331</td></tr><tr><td>val_loss</td><td>8e-05</td></tr><tr><td>val_loss_min</td><td>7e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 4, 10, 0.0)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/olwamr3s" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/olwamr3s</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_075704-olwamr3s/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_080454-2ql8nzwh</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2ql8nzwh" target="_blank">(0.0001, 10, 4, 10, 0.25)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>▆█▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▄▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▆█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>██▇▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>2e-05</td></tr><tr><td>train_loss</td><td>0.01421</td></tr><tr><td>val_loss</td><td>4e-05</td></tr><tr><td>val_loss_min</td><td>1e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 4, 10, 0.25)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2ql8nzwh" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2ql8nzwh</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_080454-2ql8nzwh/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_081335-2tgqfsm1</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2tgqfsm1" target="_blank">(0.0001, 10, 4, 10, 0.5)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00047</td></tr><tr><td>train_loss</td><td>0.01496</td></tr><tr><td>val_loss</td><td>0.00063</td></tr><tr><td>val_loss_min</td><td>0.00029</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 4, 10, 0.5)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2tgqfsm1" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2tgqfsm1</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_081335-2tgqfsm1/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_082219-rjzlqtqj</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/rjzlqtqj" target="_blank">(0.0001, 10, 6, 3, 0.0)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▅▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▇▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▅▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>4e-05</td></tr><tr><td>train_loss</td><td>0.01403</td></tr><tr><td>val_loss</td><td>0.00018</td></tr><tr><td>val_loss_min</td><td>0.00014</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 6, 3, 0.0)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/rjzlqtqj" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/rjzlqtqj</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_082219-rjzlqtqj/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_083121-1q0onpld</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1q0onpld" target="_blank">(0.0001, 10, 6, 3, 0.25)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.0003</td></tr><tr><td>train_loss</td><td>0.01552</td></tr><tr><td>val_loss</td><td>0.00033</td></tr><tr><td>val_loss_min</td><td>0.00016</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 6, 3, 0.25)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1q0onpld" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1q0onpld</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_083121-1q0onpld/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_083906-1zlfbjxv</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1zlfbjxv" target="_blank">(0.0001, 10, 6, 3, 0.5)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00208</td></tr><tr><td>train_loss</td><td>0.01804</td></tr><tr><td>val_loss</td><td>0.00222</td></tr><tr><td>val_loss_min</td><td>0.00028</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 6, 3, 0.5)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1zlfbjxv" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1zlfbjxv</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_083906-1zlfbjxv/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_084651-2w20vwm0</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2w20vwm0" target="_blank">(0.0001, 10, 6, 5, 0.0)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.0</td></tr><tr><td>train_loss</td><td>0.01313</td></tr><tr><td>val_loss</td><td>0.0</td></tr><tr><td>val_loss_min</td><td>0.0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 6, 5, 0.0)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2w20vwm0" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2w20vwm0</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_084651-2w20vwm0/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_085540-1uq1m794</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1uq1m794" target="_blank">(0.0001, 10, 6, 5, 0.25)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▅▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00017</td></tr><tr><td>train_loss</td><td>0.01355</td></tr><tr><td>val_loss</td><td>0.00018</td></tr><tr><td>val_loss_min</td><td>2e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 6, 5, 0.25)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1uq1m794" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1uq1m794</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_085540-1uq1m794/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_090511-yobqb5sg</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/yobqb5sg" target="_blank">(0.0001, 10, 6, 5, 0.5)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▇▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▆▄▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▇▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.0008</td></tr><tr><td>train_loss</td><td>0.01612</td></tr><tr><td>val_loss</td><td>0.00072</td></tr><tr><td>val_loss_min</td><td>2e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 6, 5, 0.5)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/yobqb5sg" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/yobqb5sg</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_090511-yobqb5sg/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_091438-1ulv250i</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1ulv250i" target="_blank">(0.0001, 10, 6, 7, 0.0)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▅▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▆▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>6e-05</td></tr><tr><td>train_loss</td><td>0.01247</td></tr><tr><td>val_loss</td><td>3e-05</td></tr><tr><td>val_loss_min</td><td>1e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 6, 7, 0.0)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1ulv250i" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/1ulv250i</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_091438-1ulv250i/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_092507-j815sl2i</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/j815sl2i" target="_blank">(0.0001, 10, 6, 7, 0.25)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>▁█▆▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁█▆▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00017</td></tr><tr><td>train_loss</td><td>0.01371</td></tr><tr><td>val_loss</td><td>0.00017</td></tr><tr><td>val_loss_min</td><td>0.0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 6, 7, 0.25)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/j815sl2i" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/j815sl2i</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_092507-j815sl2i/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_093618-21ubo6j9</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/21ubo6j9" target="_blank">(0.0001, 10, 6, 7, 0.5)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>▄█▅▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄█▅▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>███████▇▅▅▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00047</td></tr><tr><td>train_loss</td><td>0.0146</td></tr><tr><td>val_loss</td><td>0.00041</td></tr><tr><td>val_loss_min</td><td>2e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 6, 7, 0.5)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/21ubo6j9" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/21ubo6j9</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_093618-21ubo6j9/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_094735-2423qxmv</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2423qxmv" target="_blank">(0.0001, 10, 6, 10, 0.0)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>██▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>██▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>██▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>3e-05</td></tr><tr><td>train_loss</td><td>0.01325</td></tr><tr><td>val_loss</td><td>2e-05</td></tr><tr><td>val_loss_min</td><td>2e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 6, 10, 0.0)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2423qxmv" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2423qxmv</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_094735-2423qxmv/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_100125-d59f36jr</code>
# ...
# Find logs at: <code>./wandb/run-20220512_105200-1kfwfvsu/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_110254-2i8n4bh3</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2i8n4bh3" target="_blank">(0.0001, 10, 8, 5, 0.0)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>3e-05</td></tr><tr><td>train_loss</td><td>0.01432</td></tr><tr><td>val_loss</td><td>3e-05</td></tr><tr><td>val_loss_min</td><td>2e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 8, 5, 0.0)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2i8n4bh3" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2i8n4bh3</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_110254-2i8n4bh3/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_111631-3i6val5u</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/3i6val5u" target="_blank">(0.0001, 10, 8, 5, 0.25)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▆▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▆▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▆▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▆▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>4e-05</td></tr><tr><td>train_loss</td><td>0.0153</td></tr><tr><td>val_loss</td><td>3e-05</td></tr><tr><td>val_loss_min</td><td>1e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 8, 5, 0.25)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/3i6val5u" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/3i6val5u</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_111631-3i6val5u/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_113128-184sax2k</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/184sax2k" target="_blank">(0.0001, 10, 8, 5, 0.5)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>0.00046</td></tr><tr><td>train_loss</td><td>0.01533</td></tr><tr><td>val_loss</td><td>0.00062</td></tr><tr><td>val_loss_min</td><td>3e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 8, 5, 0.5)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/184sax2k" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/184sax2k</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_113128-184sax2k/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_114609-383i9926</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/383i9926" target="_blank">(0.0001, 10, 8, 7, 0.0)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>▇█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▇█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>██▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>2e-05</td></tr><tr><td>train_loss</td><td>0.01201</td></tr><tr><td>val_loss</td><td>4e-05</td></tr><tr><td>val_loss_min</td><td>0.0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 8, 7, 0.0)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/383i9926" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/383i9926</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_114609-383i9926/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_120444-20wh8jy6</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/20wh8jy6" target="_blank">(0.0001, 10, 8, 7, 0.25)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>▂█▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▄▃▂▂▂▂▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂█▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>████████████▇▆▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>1e-05</td></tr><tr><td>train_loss</td><td>0.01373</td></tr><tr><td>val_loss</td><td>1e-05</td></tr><tr><td>val_loss_min</td><td>0.0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 8, 7, 0.25)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/20wh8jy6" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/20wh8jy6</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_120444-20wh8jy6/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_122426-h5xo9bl0</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/h5xo9bl0" target="_blank">(0.0001, 10, 8, 7, 0.5)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>██▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▅▃▃▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>██▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>██▅▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>9e-05</td></tr><tr><td>train_loss</td><td>0.01406</td></tr><tr><td>val_loss</td><td>9e-05</td></tr><tr><td>val_loss_min</td><td>1e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 8, 7, 0.5)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/h5xo9bl0" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/h5xo9bl0</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_122426-h5xo9bl0/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_124415-2tiovfyc</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2tiovfyc" target="_blank">(0.0001, 10, 8, 10, 0.0)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>▃█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▃█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>███▆▄▄▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>1e-05</td></tr><tr><td>train_loss</td><td>0.01137</td></tr><tr><td>val_loss</td><td>2e-05</td></tr><tr><td>val_loss_min</td><td>1e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">(0.0001, 10, 8, 10, 0.0)</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2tiovfyc" target="_blank">https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2tiovfyc</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_124415-2tiovfyc/logs</code>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/drive/Shareddrives/yujung kim/Study/Python/time_series/wandb/run-20220512_131107-2uivx6b1</code>
# Syncing run <strong><a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1/runs/2uivx6b1" target="_blank">(0.0001, 10, 8, 10, 0.25)</a></strong> to <a href="https://wandb.ai/yyyyyjkim/TCN_data_composition_1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
pred_val = result_val[0]
pred_val = power_scaler.inverse_transform(pred_val[:,0,:ow].reshape(-1,1))
print(f"pred_val: {len(pred_val)}")

pred_test = result_test[0]
pred_test = power_scaler.inverse_transform(pred_test[:,0,:ow].reshape(-1,1))
print(f"pred_test: {len(pred_test)}")
# Out:
# pred_val: 480
# pred_test: 264

# %%
plt.figure(figsize=(30,5))

sns.lineplot(pv_train.loc[datetime(2006,11,1,00,tzinfo=tz):].index, pv_train.loc[datetime(2006,11,1,00,tzinfo=tz):]['power'], label='train')
sns.lineplot(pv_val.loc[datetime(2006,12,1,00,tzinfo=tz):].index, pv_val.loc[datetime(2006,12,1,00,tzinfo=tz):]['power'], label='validation_true')
sns.lineplot(pv_val.loc[datetime(2006,12,1,00,tzinfo=tz):].index, pred_val.reshape(-1), label='validation_pred')
sns.lineplot(pv_test.loc[datetime(2006,12,21,00,tzinfo=tz):].index, pv_test.loc[datetime(2006,12,21,00,tzinfo=tz):]['power'], label='test_true')
sns.lineplot(pv_test.loc[datetime(2006,12,21,00,tzinfo=tz):].index, pred_test.reshape(-1), label='test_pred')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
model.load_state_dict(torch.load(file_name))
*result_val, val_loss = predict(model, val_loader, criterion, device='cpu')
*result_test, test_loss = predict(model, test_loader, criterion, device='cpu')

# %%
pred_val = result_val[0]
pred_val = power_scaler.inverse_transform(pred_val[:,0,:ow].reshape(-1,1))
print(f"pred_val: {len(pred_val)}")

pred_test = result_test[0]
pred_test = power_scaler.inverse_transform(pred_test[:,0,:ow].reshape(-1,1))
print(f"pred_test: {len(pred_test)}")
# Out:
# pred_val: 480
# pred_test: 264

# %%
plt.figure(figsize=(30,5))

sns.lineplot(pv_train.loc[datetime(2006,11,1,00,tzinfo=tz):].index, pv_train.loc[datetime(2006,11,1,00,tzinfo=tz):]['power'], label='train')
sns.lineplot(pv_val.loc[datetime(2006,12,1,00,tzinfo=tz):].index, pv_val.loc[datetime(2006,12,1,00,tzinfo=tz):]['power'], label='validation_true')
sns.lineplot(pv_val.loc[datetime(2006,12,1,00,tzinfo=tz):].index, pred_val.reshape(-1), label='validation_pred')
sns.lineplot(pv_test.loc[datetime(2006,12,21,00,tzinfo=tz):].index, pv_test.loc[datetime(2006,12,21,00,tzinfo=tz):]['power'], label='test_true')
sns.lineplot(pv_test.loc[datetime(2006,12,21,00,tzinfo=tz):].index, pred_test.reshape(-1), label='test_pred')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # 단일 모델

# %%
# pv 만 예측하는 경우 output_size=1
# 기상 정보 같이 예측하는 경우 output_size=input_size -> x 

wandb.config = {
    "learning_rate": lr[0],
    "epochs": 100,
    "input_size": 8,
    "output_size": 1,
    "num_channels": [num_hidden[0]]*num_levels[0],
    "kernel_size": kernel_size[0], 
    "dropout": dropout[0]
}

# %%
device='cpu'
model = TCN(input_size=wandb.config['input_size'], output_size=wandb.config['output_size'], num_channels=wandb.config['num_channels'], kernel_size=wandb.config['kernel_size'], dropout=wandb.config['dropout']).to(device)
optimizer = optim.Adam(model.parameters(), lr=wandb.config['learning_rate'])
criterion = nn.MSELoss()

# %%
# 파라미터 수 계산
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 2,601 trainable parameters

# %%
wandb.watch(model, log='all', log_freq=10)

val_loss_min = 100
file_name = 'model/basic.model'

pbar = tqdm(range(wandb.config['epochs']))
for epoch in pbar:
    *result_train, train_loss = train(model, train_loader, optimizer, criterion, device='cpu')
    *result_val, val_loss = predict(model, val_loader, criterion, device='cpu')
    *result_test, test_loss = predict(model, test_loader, criterion, device='cpu')

    if val_loss < val_loss_min:
        val_loss_min = val_loss
        torch.save(model.state_dict(), file_name)
        print(f"epoch: {epoch} / val_loss: {val_loss:.5f} / test_loss: {test_loss:.5f}")

    wandb.log({"train_loss": train_loss, "val_loss": val_loss, "test_loss": test_loss, "val_loss_min": val_loss_min})

    pbar.set_postfix(loss=f"train_loss: {train_loss:.5f} / val_loss: {val_loss:.5f} / test_loss: {test_loss:.5f}")

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>████▇▇▇▇▆▆▅▅▅▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>███▇▇▇▆▆▆▆▅▅▄▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>████▇▇▇▇▆▆▅▅▅▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss_min</td><td>█████▇▇▇▆▆▆▅▅▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_loss</td><td>2e-05</td></tr><tr><td>train_loss</td><td>0.01507</td></tr><tr><td>val_loss</td><td>5e-05</td></tr><tr><td>val_loss_min</td><td>4e-05</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">base</strong>: <a href="https://wandb.ai/yyyyyjkim/TCN/runs/3qmnry11" target="_blank">https://wandb.ai/yyyyyjkim/TCN/runs/3qmnry11</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220512_064049-3qmnry11/logs</code>

# %%
pred_val = result_val[0]
pred_val = power_scaler.inverse_transform(pred_val[:,0,:ow].reshape(-1,1))
print(f"pred_val: {len(pred_val)}")

pred_test = result_test[0]
pred_test = power_scaler.inverse_transform(pred_test[:,0,:ow].reshape(-1,1))
print(f"pred_test: {len(pred_test)}")
# Out:
# pred_val: 480
# pred_test: 264

# %%
plt.figure(figsize=(30,5))

sns.lineplot(pv_train.loc[datetime(2006,11,1,00,tzinfo=tz):].index, pv_train.loc[datetime(2006,11,1,00,tzinfo=tz):]['power'], label='train')
sns.lineplot(pv_val.loc[datetime(2006,12,1,00,tzinfo=tz):].index, pv_val.loc[datetime(2006,12,1,00,tzinfo=tz):]['power'], label='validation_true')
sns.lineplot(pv_val.loc[datetime(2006,12,1,00,tzinfo=tz):].index, pred_val.reshape(-1), label='validation_pred')
sns.lineplot(pv_test.loc[datetime(2006,12,21,00,tzinfo=tz):].index, pv_test.loc[datetime(2006,12,21,00,tzinfo=tz):]['power'], label='test_true')
sns.lineplot(pv_test.loc[datetime(2006,12,21,00,tzinfo=tz):].index, pred_test.reshape(-1), label='test_pred')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
model.load_state_dict(torch.load(file_name))
*result_val, val_loss = predict(model, val_loader, criterion, device='cpu')
*result_test, test_loss = predict(model, test_loader, criterion, device='cpu')

# %%
pred_val = result_val[0]
pred_val = power_scaler.inverse_transform(pred_val[:,0,:ow].reshape(-1,1))
print(f"pred_val: {len(pred_val)}")

pred_test = result_test[0]
pred_test = power_scaler.inverse_transform(pred_test[:,0,:ow].reshape(-1,1))
print(f"pred_test: {len(pred_test)}")
# Out:
# pred_val: 480
# pred_test: 264

# %%
plt.figure(figsize=(30,5))

sns.lineplot(pv_train.loc[datetime(2006,11,1,00,tzinfo=tz):].index, pv_train.loc[datetime(2006,11,1,00,tzinfo=tz):]['power'], label='train')
sns.lineplot(pv_val.loc[datetime(2006,12,1,00,tzinfo=tz):].index, pv_val.loc[datetime(2006,12,1,00,tzinfo=tz):]['power'], label='validation_true')
sns.lineplot(pv_val.loc[datetime(2006,12,1,00,tzinfo=tz):].index, pred_val.reshape(-1), label='validation_pred')
sns.lineplot(pv_test.loc[datetime(2006,12,21,00,tzinfo=tz):].index, pv_test.loc[datetime(2006,12,21,00,tzinfo=tz):]['power'], label='test_true')
sns.lineplot(pv_test.loc[datetime(2006,12,21,00,tzinfo=tz):].index, pred_test.reshape(-1), label='test_pred')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
test_loss
# Out:
# 1.809760033211205e-05
